# %%
import pandas as pd

# %%
output_path = '/dbfs/FileStore/tables/transactions/products.csv'

# %%
data = [
    {"product_id": 1, "product_name": "Smartphone", "category": "Electronics", "brand": "Samsung"},
    {"product_id": 2, "product_name": "Laptop", "category": "Electronics", "brand": "Dell"},
    {"product_id": 3, "product_name": "Headphones", "category": "Electronics", "brand": "Sony"},
    {"product_id": 4, "product_name": "Sneakers", "category": "Fashion", "brand": "Nike"},
    {"product_id": 5, "product_name": "T-shirt", "category": "Fashion", "brand": "Uniqlo"},
    {"product_id": 6, "product_name": "Coffee Maker", "category": "Home", "brand": "Philips"},
    {"product_id": 7, "product_name": "Vacuum Cleaner", "category": "Home", "brand": "Dyson"},
    {"product_id": 8, "product_name": "Novel", "category": "Books", "brand": "Penguin"},
    {"product_id": 9, "product_name": "Gaming Console", "category": "Electronics", "brand": "Nintendo"},
    {"product_id": 10, "product_name": "Mountain Bike", "category": "Sports", "brand": "Trek"}
]

# %%
df = pd.DataFrame(data)

# %%
df.to_csv(output_path)
